# %%
from sqlalchemy import create_engine

# %%
#premise_file = "../Resources/LicensePremise.csv"
premise_df = pd.read_csv(premise_file)
premise_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-11686d1eb4bd> in <module>
#       1 #premise_file = "../Resources/LicensePremise.csv"
# ----> 2 premise_df = pd.read_csv(premise_file)
#       3 premise_df.head()
#
# NameError: name 'pd' is not defined

# %%
connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# C:\Users\malki\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2976         try:
# -> 2977             return fn()
#    2978         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     700         if not fairy:
# --> 701             fairy = _ConnectionRecord.checkout(pool)
#     702
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     420     def checkout(cls, pool):
# --> 421         rec = pool._do_get()
#     422         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141                 with util.safe_reraise():
# --> 142                     self._dec_overflow()
#     143         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                     exc_value,
# ---> 71                     with_traceback=exc_tb,
#      72                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     179         try:
# --> 180             raise exception
#     181         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             try:
# --> 139                 return self._create_connection()
#     140             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     248
# --> 249         return _ConnectionRecord(self)
#     250
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     363         if connect:
# --> 364             self.__connect(first_connect_check=True)
#     365         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     587             with util.safe_reraise():
# --> 588                 pool.logger.debug("Error on connect(): %s", e)
#     589         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                     exc_value,
# ---> 71                     with_traceback=exc_tb,
#      72                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     179         try:
# --> 180             raise exception
#     181         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     581             self.starttime = time.time()
# --> 582             connection = pool._invoke_creator(self)
#     583             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     566                         return connection
# --> 567             return dialect.connect(*cargs, **cparams)
#     568
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     529         # inherits the docstring from interfaces.Dialect.connect
# --> 530         return self.dbapi.connect(*cargs, **cparams)
#     531
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# <string> in table_names(self, schema, connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     367         if not skip_warning:
#     368             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 369         return fn(*args, **kwargs)
#     370
#     371     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2945         :param connection: Optional, use a specified connection.
#    2946         """
# -> 2947         with self._optional_conn_ctx_manager(connection) as conn:
#    2948             insp = inspection.inspect(conn)
#    2949             return insp.get_table_names(schema)
#
# ~\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2695     def _optional_conn_ctx_manager(self, connection=None):
#    2696         if connection is None:
# -> 2697             with self.connect() as conn:
#    2698                 yield conn
#    2699         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    2929         """
#    2930
# -> 2931         return self._connection_cls(self, close_with_result=close_with_result)
#    2932
#    2933     @util.deprecated(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      86                 connection
#      87                 if connection is not None
# ---> 88                 else engine.raw_connection()
#      89             )
#      90
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3008
#    3009         """
# -> 3010         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3011
#    3012
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2979             if connection is None:
#    2980                 Connection._handle_dbapi_exception_noconnection(
# -> 2981                     e, dialect, self
#    2982                 )
#    2983             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1925         elif should_wrap:
#    1926             util.raise_(
# -> 1927                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1928             )
#    1929         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     178
#     179         try:
# --> 180             raise exception
#     181         finally:
#     182             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2975         dialect = self.dialect
#    2976         try:
# -> 2977             return fn()
#    2978         except dialect.dbapi.Error as e:
#    2979             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     301
#     302         """
# --> 303         return _ConnectionFairy._checkout(self)
#     304
#     305     def _return_conn(self, record):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     699     def _checkout(cls, pool, threadconns=None, fairy=None):
#     700         if not fairy:
# --> 701             fairy = _ConnectionRecord.checkout(pool)
#     702
#     703             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     419     @classmethod
#     420     def checkout(cls, pool):
# --> 421         rec = pool._do_get()
#     422         try:
#     423             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140             except:
#     141                 with util.safe_reraise():
# --> 142                     self._dec_overflow()
#     143         else:
#     144             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                 compat.raise_(
#      70                     exc_value,
# ---> 71                     with_traceback=exc_tb,
#      72                 )
#      73         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     178
#     179         try:
# --> 180             raise exception
#     181         finally:
#     182             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137         if self._inc_overflow():
#     138             try:
# --> 139                 return self._create_connection()
#     140             except:
#     141                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     247         """Called by subclasses to create a new ConnectionRecord."""
#     248
# --> 249         return _ConnectionRecord(self)
#     250
#     251     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     362         self.__pool = pool
#     363         if connect:
# --> 364             self.__connect(first_connect_check=True)
#     365         self.finalize_callback = deque()
#     366
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     586         except Exception as e:
#     587             with util.safe_reraise():
# --> 588                 pool.logger.debug("Error on connect(): %s", e)
#     589         else:
#     590             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                 compat.raise_(
#      70                     exc_value,
# ---> 71                     with_traceback=exc_tb,
#      72                 )
#      73         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     178
#     179         try:
# --> 180             raise exception
#     181         finally:
#     182             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     580         try:
#     581             self.starttime = time.time()
# --> 582             connection = pool._invoke_creator(self)
#     583             pool.logger.debug("Created new connection %r", connection)
#     584             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     565                     if connection is not None:
#     566                         return connection
# --> 567             return dialect.connect(*cargs, **cparams)
#     568
#     569         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     528     def connect(self, *cargs, **cparams):
#     529         # inherits the docstring from interfaces.Dialect.connect
# --> 530         return self.dbapi.connect(*cargs, **cparams)
#     531
#     532     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
