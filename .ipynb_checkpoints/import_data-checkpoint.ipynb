# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
movies_file = "Resources/MoviesOnStreamingPlatforms_updated.csv"
movies_df = pd.read_csv(movies_file)
movies_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
tvshows_file = "Resources/All_Streaming_Shows.csv"
tvshows_df = pd.read_csv(tvshows_file)
tvshows_df.head()
# Out:
#       Series Title  Year Released Content Rating  IMDB Rating  R Rating  \
# 0     Breaking Bad           2008            18+          9.5       100
# 1  Game of Thrones           2011            18+          9.3        99
# 2   Rick and Morty           2013            18+          9.2        97
# 3  Stranger Things           2016            16+          8.8        96
# 4         The Boys           2019            18+          8.7        95
#
#                        Genre  \
# 0                Crime,Drama
# 1   Action & Adventure,Drama
# 2           Animation,Comedy
# 3              Drama,Fantasy
# 4  Action & Adventure,Comedy
#
#                                          Description No of Seasons  \
# 0  When Walter White, a New Mexico chemistry teac...      5Seasons
# 1  Seven noble families fight for control of the ...      8Seasons
# 2  Rick is a mentally-unbalanced but scientifical...      4Seasons
# 3  When a young boy vanishes, a small town uncove...      3Seasons
# ...

# %%
# JoshBrar 12/2/2020 - get all unique genras from movie and shows csv files and load it to genras_tbl

#tvshows_df.iloc['Genre']
#tvshows_df.iloc[1]
#tvshows_df['Genre']
varx =  tvshows_df.loc[:]['Genre']
varx
vary=[]
for x in  tvshows_df['Genre']:
    #vary.append(x.split(sep=','))
    vary +=x.split(sep=',')
   
vary
# Out:
# ['Crime',
#  'Drama',
#  'Action & Adventure',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Action & Adventure',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Drama',
#  'History',
#  'Action & Adventure',
#  'Crime',
#  'Crime',
#  'Drama',
#  'Action & Adventure',
#  'Animation',
#  'Comedy',
#  'Romance',
#  'Comedy',
#  '2005',
#  'Drama',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Action & Adventure',
#  'Anime',
#  'Drama',
#  'Science-Fiction',
#  'Action & Adventure',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Fantasy',
#  'Crime',
#  'Thriller',
#  'Action & Adventure',
#  'Drama',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Action & Adventure',
#  'Drama',
#  'Animation',
#  'Comedy',
#  'Action & Adventure',
#  'Science-Fiction',
#  'Crime',
#  'Drama',
#  'Action & Adventure',
#  'Comedy',
#  'Action & Adventure',
#  'Drama',
#  'Drama',
#  'Horror',
#  'Action & Adventure',
#  'Drama',
#  'Comedy',
#  'Crime',
#  'Comedy',
# ...

# %%
genras_df = pd.DataFrame({'genras_name' : vary})
genras_df[:1000].genras_name.unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1ca1b132111d> in <module>
#       1 genras_df = pd.DataFrame({'genras_name' : vary})
# ----> 2 genras_df[:1000,].genras_name.unique()
#       3
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             casted_key = self._maybe_cast_indexer(key)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
# ...

# %%
connection_string = "postgres:Program2@localhost:543vary2/ETL_Project_14"
engine = create_engine(f'postgresql://{vary}')

# %%
# Confirm tables
engine.table_names()
# Out:
# C:\Users\malki\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['genras_tbl', 'movies_tbl', 'movies_shows_genras_tbl', 'tv_shows_tbl']
